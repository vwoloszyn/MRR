# %% [markdown]
# ## REVRANK: A Fully Unsupervised Algorithm for Selecting the Most Helpful Book Reviews
# ### by Oren Tsur and Ari Rappoport

# %%
import nltk
import math
import time
import itertools
import operator
import pandas as pd
from nltk.corpus import brown, stopwords
AllReviews = pd.read_csv('data/book_sample_counts.csv.gz')
min_comments=30
min_votes=5

# %% [markdown]
# ### build Virtual Core Review

# %%
def virtual_core(reviewsDf, external_freq, c, m):
    
    texts = [nltk.word_tokenize(text) for text in reviewsDf.reviewText]
    tokens = list(itertools.chain(*texts))
    reviews_freq = nltk.FreqDist(tokens)

    dominance = dict([])
    
    for word in dict(reviews_freq):
        if external_freq[word] > 0 and math.log(external_freq[word],2) > 0 and (word.lower() not in stopwords.words('english')) and (len(word) > 2):
            dominance[word] = reviews_freq[word] * c * ( 1 / math.log(external_freq[word],2) )
    
    
    return sorted(dominance.items(), key=operator.itemgetter(1), reverse=True)[:m]

# %%
brown_freq = nltk.FreqDist(brown.words(categories="news"))
grouped = AllReviews[AllReviews['tot'].astype(int)>min_votes].groupby('asin')

# evaluate virtual core function
for name, group in grouped:
    
    ProductReview = AllReviews[AllReviews['asin']==name]    
    review_core = virtual_core(ProductReview, brown_freq, 3, 200)
    
    break

# %% [markdown]
# ### build Review Score

# %%
def review_score(text, core, mean):
    core_dict = dict(core)
    review_vector = nltk.FreqDist(nltk.word_tokenize(text))
    length = len(nltk.word_tokenize(text))
    score = 0

    for word in review_vector:
        if word in core_dict:
            score += review_vector[word]

    p = 1
    if length < mean:
        p = 20
            
    return (float(1) / p) * (float(score) / length)

# %%
# evaluate review_score function
mean = ProductReview.word_count.mean()
review_s = review_score(ProductReview.reviewText[0], review_core, mean)
review_s
# Out:
# 0.007407407407407408

# %% [markdown]
# ### run RevRank for all instances

# %%
def zeroFun(x): return 0

total = len(grouped)
run = 1
performance=[]

for name, group in grouped:
    
    ProductReview = AllReviews[AllReviews['asin']==name] 
    run += 1
    
    if ( len(ProductReview)>min_comments ):
    
        ProductReview['revRank'] = ProductReview.apply(zeroFun,axis=1)

        start = time.time()
        
        review_core = virtual_core(ProductReview, brown_freq, 3, 200)
        mean = ProductReview.word_count.mean()

        for t in ProductReview.T.to_dict().values():
            review_s = review_score(t['reviewText'], review_core, mean)
            AllReviews.loc[t.values()[0],'revRank'] = review_s

        end = time.time()
        elapsed = (end - start)
            
        tempo={}
        tempo['product']=name
        tempo['tot_product']= len(ProductReview)
        tempo['time']=elapsed
        performance.append(tempo)
            
        print("Run %d size %d for %d" % (run, len(ProductReview), total))
            
        #break

pd.DataFrame(performance).to_csv('data/performance_revRank_book.csv.gz', compression='gzip')
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Run 2 size 48 for 461
# Run 3 size 80 for 461
# Run 4 size 31 for 461
# Run 5 size 56 for 461
# Run 6 size 45 for 461
# Run 7 size 58 for 461
# Run 8 size 35 for 461
# Run 9 size 54 for 461
# Run 10 size 40 for 461
# Run 11 size 131 for 461
# Run 12 size 60 for 461
# Run 13 size 40 for 461
# Run 14 size 36 for 461
# Run 15 size 40 for 461
# Run 16 size 46 for 461
# Run 17 size 74 for 461
# Run 18 size 36 for 461
# Run 19 size 53 for 461
# Run 20 size 43 for 461
# Run 21 size 33 for 461
# Run 22 size 74 for 461
# Run 23 size 116 for 461
# Run 24 size 57 for 461
# Run 25 size 39 for 461
# Run 26 size 35 for 461
# Run 27 size 146 for 461
# Run 28 size 46 for 461
# Run 29 size 53 for 461
# Run 30 size 77 for 461
# Run 31 size 115 for 461
# Run 32 size 49 for 461
# Run 33 size 39 for 461
# Run 34 size 34 for 461
# Run 35 size 70 for 461
# Run 36 size 65 for 461
# Run 37 size 60 for 461
# Run 38 size 85 for 461
# Run 39 size 88 for 461
# Run 40 size 31 for 461
# Run 41 size 33 for 461
# Run 42 size 65 for 461
# Run 43 size 37 for 461
# Run 44 size 34 for 461
# Run 45 size 31 for 461
# Run 46 size 46 for 461
# Run 47 size 33 for 461
# Run 48 size 41 for 461
# Run 49 size 61 for 461
# Run 50 size 60 for 461
# Run 51 size 147 for 461
# Run 52 size 52 for 461
# Run 53 size 37 for 461
# Run 54 size 59 for 461
# Run 55 size 121 for 461
# Run 56 size 75 for 461
# Run 57 size 47 for 461
# Run 58 size 32 for 461
# Run 59 size 42 for 461
# Run 60 size 37 for 461
# Run 61 size 45 for 461
# Run 62 size 31 for 461
# Run 63 size 81 for 461
# Run 64 size 43 for 461
# Run 65 size 40 for 461
# Run 66 size 40 for 461
# Run 67 size 49 for 461
# Run 68 size 59 for 461
# Run 69 size 33 for 461
# Run 70 size 48 for 461
# Run 71 size 34 for 461
# Run 72 size 32 for 461
# Run 73 size 33 for 461
# Run 74 size 38 for 461
# Run 75 size 44 for 461
# Run 76 size 42 for 461
# Run 77 size 57 for 461
# Run 78 size 31 for 461
# Run 79 size 36 for 461
# Run 80 size 33 for 461
# Run 81 size 31 for 461
# Run 82 size 85 for 461
# Run 83 size 59 for 461
# Run 84 size 33 for 461
# Run 85 size 31 for 461
# Run 86 size 137 for 461
# Run 87 size 86 for 461
# Run 88 size 39 for 461
# Run 89 size 38 for 461
# Run 90 size 32 for 461
# Run 91 size 113 for 461
# Run 92 size 43 for 461
# Run 93 size 54 for 461
# Run 94 size 91 for 461
# Run 95 size 41 for 461
# Run 96 size 36 for 461
# Run 97 size 48 for 461
# Run 98 size 45 for 461
# Run 99 size 32 for 461
# Run 100 size 31 for 461
# Run 101 size 34 for 461
# Run 102 size 49 for 461
# Run 103 size 46 for 461
# Run 104 size 36 for 461
# Run 105 size 42 for 461
# Run 106 size 31 for 461
# Run 107 size 31 for 461
# Run 108 size 39 for 461
# Run 109 size 36 for 461
# Run 110 size 74 for 461
# Run 111 size 42 for 461
# Run 112 size 66 for 461
# Run 113 size 34 for 461
# Run 114 size 34 for 461
# Run 115 size 86 for 461
# Run 116 size 46 for 461
# Run 117 size 31 for 461
# Run 118 size 78 for 461
# Run 119 size 43 for 461
# Run 120 size 57 for 461
# Run 121 size 31 for 461
# Run 122 size 46 for 461
# Run 123 size 84 for 461
# Run 124 size 34 for 461
# Run 125 size 53 for 461
# Run 126 size 88 for 461
# Run 127 size 42 for 461
# Run 128 size 34 for 461
# Run 129 size 45 for 461
# Run 130 size 81 for 461
# Run 131 size 34 for 461
# Run 132 size 37 for 461
# Run 133 size 59 for 461
# Run 134 size 33 for 461
# Run 135 size 55 for 461
# Run 136 size 49 for 461
# Run 137 size 32 for 461
# Run 138 size 33 for 461
# Run 139 size 101 for 461
# Run 140 size 63 for 461
# Run 141 size 37 for 461
# Run 142 size 59 for 461
# Run 143 size 64 for 461
# Run 144 size 40 for 461
# Run 145 size 50 for 461
# Run 146 size 62 for 461
# Run 147 size 87 for 461
# Run 148 size 41 for 461
# Run 149 size 38 for 461
# Run 150 size 89 for 461
# Run 151 size 47 for 461
# Run 152 size 130 for 461
# Run 153 size 32 for 461
# Run 154 size 32 for 461
# Run 155 size 144 for 461
# Run 156 size 35 for 461
# Run 157 size 41 for 461
# Run 158 size 83 for 461
# Run 159 size 76 for 461
# Run 160 size 67 for 461
# Run 161 size 48 for 461
# Run 162 size 36 for 461
# Run 163 size 100 for 461
# Run 164 size 35 for 461
# Run 165 size 47 for 461
# Run 166 size 36 for 461
# Run 167 size 40 for 461
# Run 168 size 65 for 461
# Run 169 size 66 for 461
# Run 170 size 31 for 461
# Run 171 size 33 for 461
# Run 172 size 38 for 461
# Run 173 size 41 for 461
# Run 174 size 80 for 461
# Run 175 size 109 for 461
# Run 176 size 46 for 461
# Run 177 size 49 for 461
# Run 178 size 133 for 461
# Run 179 size 42 for 461
# Run 180 size 71 for 461
# Run 181 size 52 for 461
# Run 182 size 106 for 461
# Run 183 size 68 for 461
# Run 184 size 68 for 461
# Run 185 size 86 for 461
# Run 186 size 71 for 461
# Run 187 size 32 for 461
# Run 188 size 57 for 461
# Run 189 size 63 for 461
# Run 190 size 38 for 461
# Run 191 size 58 for 461
# Run 192 size 40 for 461
# Run 193 size 36 for 461
# Run 194 size 41 for 461
# Run 195 size 101 for 461
# Run 196 size 44 for 461
# Run 197 size 48 for 461
# Run 198 size 33 for 461
# Run 199 size 53 for 461
# Run 200 size 50 for 461
# Run 201 size 38 for 461
# Run 202 size 40 for 461
# Run 203 size 39 for 461
# Run 204 size 43 for 461
# Run 205 size 41 for 461
# Run 206 size 61 for 461
# Run 207 size 95 for 461
# Run 208 size 66 for 461
# Run 209 size 37 for 461
# Run 210 size 35 for 461
# Run 211 size 42 for 461
# Run 212 size 45 for 461
# Run 213 size 42 for 461
# Run 214 size 42 for 461
# Run 215 size 72 for 461
# Run 216 size 55 for 461
# Run 217 size 33 for 461
# Run 218 size 37 for 461
# Run 219 size 51 for 461
# Run 220 size 33 for 461
# Run 221 size 93 for 461
# Run 222 size 33 for 461
# Run 223 size 67 for 461
# Run 224 size 55 for 461
# Run 225 size 73 for 461
# Run 226 size 31 for 461
# Run 227 size 41 for 461
# Run 228 size 35 for 461
# Run 229 size 35 for 461
# Run 230 size 71 for 461
# Run 231 size 61 for 461
# Run 232 size 36 for 461
# Run 233 size 52 for 461
# Run 234 size 43 for 461
# Run 235 size 32 for 461
# Run 236 size 45 for 461
# Run 237 size 67 for 461
# Run 238 size 78 for 461
# Run 239 size 37 for 461
# Run 240 size 36 for 461
# Run 241 size 107 for 461
# Run 242 size 98 for 461
# Run 243 size 35 for 461
# Run 244 size 41 for 461
# Run 245 size 35 for 461
# Run 246 size 67 for 461
# Run 247 size 71 for 461
# Run 248 size 35 for 461
# Run 249 size 72 for 461
# Run 250 size 36 for 461
# Run 251 size 41 for 461
# Run 252 size 60 for 461
# Run 253 size 31 for 461
# Run 254 size 67 for 461
# Run 255 size 38 for 461
# Run 256 size 37 for 461
# Run 257 size 37 for 461
# Run 258 size 51 for 461
# Run 259 size 33 for 461
# Run 260 size 45 for 461
# Run 261 size 41 for 461
# Run 262 size 56 for 461
# Run 263 size 87 for 461
# Run 264 size 40 for 461
# Run 265 size 32 for 461
# Run 266 size 84 for 461
# Run 267 size 113 for 461
# Run 268 size 68 for 461
# Run 269 size 45 for 461
# Run 270 size 35 for 461
# Run 271 size 74 for 461
# Run 272 size 43 for 461
# Run 273 size 42 for 461
# Run 274 size 44 for 461
# Run 275 size 44 for 461
# Run 276 size 33 for 461
# Run 277 size 31 for 461
# Run 278 size 52 for 461
# Run 279 size 41 for 461
# Run 280 size 39 for 461
# Run 281 size 31 for 461
# Run 282 size 46 for 461
# Run 283 size 33 for 461
# Run 284 size 122 for 461
# Run 285 size 123 for 461
# Run 286 size 61 for 461
# Run 287 size 55 for 461
# Run 288 size 71 for 461
# Run 289 size 31 for 461
# Run 290 size 57 for 461
# Run 291 size 76 for 461
# Run 292 size 40 for 461
# Run 293 size 37 for 461
# Run 294 size 36 for 461
# Run 295 size 122 for 461
# Run 296 size 78 for 461
# Run 297 size 33 for 461
# Run 298 size 34 for 461
# Run 299 size 34 for 461
# Run 300 size 50 for 461
# Run 301 size 40 for 461
# Run 302 size 55 for 461
# Run 303 size 67 for 461
# Run 304 size 61 for 461
# Run 305 size 42 for 461
# Run 306 size 36 for 461
# Run 307 size 54 for 461
# Run 308 size 32 for 461
# Run 309 size 31 for 461
# Run 310 size 39 for 461
# Run 311 size 61 for 461
# Run 312 size 134 for 461
# Run 313 size 65 for 461
# Run 314 size 34 for 461
# Run 315 size 37 for 461
# Run 316 size 34 for 461
# Run 317 size 40 for 461
# Run 318 size 62 for 461
# Run 319 size 91 for 461
# Run 320 size 106 for 461
# Run 321 size 110 for 461
# Run 322 size 45 for 461
# Run 323 size 50 for 461
# Run 324 size 32 for 461
# Run 325 size 51 for 461
# Run 326 size 31 for 461
# Run 327 size 37 for 461
# Run 328 size 33 for 461
# Run 329 size 55 for 461
# Run 330 size 71 for 461
# Run 331 size 36 for 461
# Run 332 size 31 for 461
# Run 333 size 45 for 461
# Run 334 size 40 for 461
# Run 335 size 42 for 461
# Run 336 size 34 for 461
# Run 337 size 111 for 461
# Run 338 size 36 for 461
# Run 339 size 34 for 461
# Run 340 size 49 for 461
# Run 341 size 41 for 461
# Run 342 size 33 for 461
# Run 343 size 37 for 461
# Run 344 size 50 for 461
# Run 345 size 64 for 461
# Run 346 size 31 for 461
# Run 347 size 70 for 461
# Run 348 size 38 for 461
# Run 349 size 38 for 461
# Run 350 size 35 for 461
# Run 351 size 50 for 461
# Run 352 size 48 for 461
# Run 353 size 32 for 461
# Run 354 size 39 for 461
# Run 355 size 34 for 461
# Run 356 size 31 for 461
# Run 357 size 45 for 461
# Run 358 size 53 for 461
# Run 359 size 32 for 461
# Run 360 size 104 for 461
# Run 361 size 35 for 461
# Run 362 size 43 for 461
# Run 363 size 51 for 461
# Run 364 size 31 for 461
# Run 365 size 49 for 461
# Run 366 size 50 for 461
# Run 367 size 48 for 461
# Run 368 size 41 for 461
# Run 369 size 58 for 461
# Run 370 size 33 for 461
# Run 371 size 37 for 461
# Run 372 size 38 for 461
# Run 373 size 47 for 461
# Run 374 size 40 for 461
# Run 375 size 61 for 461
# Run 376 size 33 for 461
# Run 377 size 35 for 461
# Run 378 size 106 for 461
# Run 379 size 31 for 461
# Run 380 size 32 for 461
# Run 381 size 57 for 461
# Run 382 size 55 for 461
# Run 383 size 33 for 461
# Run 384 size 51 for 461
# Run 385 size 44 for 461
# Run 386 size 32 for 461
# Run 387 size 31 for 461
# Run 388 size 36 for 461
# Run 389 size 78 for 461
# Run 390 size 38 for 461
# Run 391 size 38 for 461
# Run 392 size 72 for 461
# Run 393 size 147 for 461
# Run 394 size 57 for 461
# Run 395 size 74 for 461
# Run 396 size 108 for 461
# Run 397 size 39 for 461
# Run 398 size 49 for 461
# Run 399 size 60 for 461
# Run 400 size 59 for 461
# Run 401 size 40 for 461
# Run 402 size 62 for 461
# Run 403 size 41 for 461
# Run 404 size 36 for 461
# Run 405 size 103 for 461
# Run 406 size 127 for 461
# Run 407 size 33 for 461
# Run 408 size 38 for 461
# Run 409 size 42 for 461
# Run 410 size 40 for 461
# Run 411 size 38 for 461
# Run 412 size 61 for 461
# Run 413 size 44 for 461
# Run 414 size 48 for 461
# Run 415 size 54 for 461
# Run 416 size 47 for 461
# Run 417 size 34 for 461
# Run 418 size 45 for 461
# Run 419 size 47 for 461
# Run 420 size 34 for 461
# Run 421 size 32 for 461
# Run 422 size 40 for 461
# Run 423 size 45 for 461
# Run 424 size 42 for 461
# Run 425 size 43 for 461
# Run 426 size 31 for 461
# Run 427 size 32 for 461
# Run 428 size 60 for 461
# Run 429 size 132 for 461
# Run 430 size 32 for 461
# Run 431 size 47 for 461
# Run 432 size 33 for 461
# Run 433 size 45 for 461
# Run 434 size 82 for 461
# Run 435 size 79 for 461
# Run 436 size 117 for 461
# Run 437 size 51 for 461
# Run 438 size 55 for 461
# Run 439 size 32 for 461
# Run 440 size 36 for 461
# Run 441 size 50 for 461
# Run 442 size 32 for 461
# Run 443 size 50 for 461
# Run 444 size 34 for 461
# Run 445 size 41 for 461
# Run 446 size 57 for 461
# Run 447 size 42 for 461
# Run 448 size 43 for 461
# Run 449 size 33 for 461
# Run 450 size 34 for 461
# Run 451 size 44 for 461
# Run 452 size 59 for 461
# Run 453 size 35 for 461
# Run 454 size 32 for 461
# Run 455 size 37 for 461
# Run 456 size 37 for 461
# Run 457 size 36 for 461
# Run 458 size 38 for 461
# Run 459 size 32 for 461
# Run 460 size 48 for 461
# Run 461 size 85 for 461
# Run 462 size 104 for 461

# %%
AllReviews.to_csv('data/book_sample_counts.csv.gz', compression='gzip')
