# %% [markdown]
# ## REVRANK: A Fully Unsupervised Algorithm for Selecting the Most Helpful Book Reviews
# ### by Oren Tsur and Ari Rappoport

# %%
import nltk
import math
import time
import itertools
import operator
import numpy as np
import pandas as pd
import NDCG as ndcg
from nltk.corpus import brown, stopwords
AllReviews = pd.read_csv('data/eletronic_sample_counts.csv.gz')
min_comments=30
min_votes=5

# %% [markdown]
# ### build Virtual Core Review

# %%
def virtual_core(reviewsDf, external_freq, c, m):
    
    texts = [nltk.word_tokenize(text) for text in reviewsDf.reviewText]
    tokens = list(itertools.chain(*texts))
    reviews_freq = nltk.FreqDist(tokens)

    dominance = dict([])
    
    for word in dict(reviews_freq):
        if external_freq[word] > 0 and math.log(external_freq[word],2) > 0 and (word.lower() not in stopwords.words('english')) and (len(word) > 2):
            dominance[word] = reviews_freq[word] * c * ( 1 / math.log(external_freq[word],2) )
    
    
    return sorted(dominance.items(), key=operator.itemgetter(1), reverse=True)[:m]

# %% [markdown]
# ### build Review Score

# %%
def review_score(text, core, mean):
    core_dict = dict(core)
    review_vector = nltk.FreqDist(nltk.word_tokenize(text))
    length = len(nltk.word_tokenize(text))
    score = 0

    for word in review_vector:
        if word in core_dict:
            score += review_vector[word]

    p = 1
    if length < mean:
        p = 20
            
    return (float(1) / p) * (float(score) / length)

# %% [markdown]
# ### run RevRank for all instances

# %%
def zeroFun(x): return 0
brown_freq = nltk.FreqDist(brown.words(categories="news"))

AllReviews['revRank'] = AllReviews.apply(zeroFun,axis=1)
grouped = AllReviews[AllReviews.tot > min_votes].groupby('asin')

total = len(grouped)
run = 0
performance=[]

for name, group in grouped:

    ProductReview = AllReviews[AllReviews['asin']==name] 
    
    if ( len(ProductReview)>min_comments):
    
        run += 1
    
        ProductReview['revRank'] = ProductReview.apply(zeroFun,axis=1)

        start = time.time()
        
        review_core = virtual_core(ProductReview, brown_freq, 3, 200)
        mean = ProductReview.word_count.mean()

        for t in ProductReview.T.to_dict().values():
            review_s = review_score(t['reviewText'], review_core, mean)
            AllReviews.loc[t.values()[0],'revRank'] = review_s

        end = time.time()
        elapsed = (end - start)
            
        tempo={}
        tempo['product']=name
        tempo['tot_product']= len(ProductReview)
        tempo['time']=elapsed
        performance.append(tempo)
            
        print("Run %d size %d for %d" % (run, len(ProductReview), total))
            
        #if run > 50:
            #break

#pd.DataFrame(performance).to_csv('data/performance_revRank.csv.gz', compression='gzip')
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Run 1 size 40 for 383
# Run 2 size 33 for 383
# Run 3 size 31 for 383
# Run 4 size 32 for 383
# Run 5 size 35 for 383
# Run 6 size 35 for 383
# Run 7 size 34 for 383
# Run 8 size 45 for 383
# Run 9 size 32 for 383
# Run 10 size 39 for 383
# Run 11 size 68 for 383
# Run 12 size 58 for 383
# Run 13 size 40 for 383
# Run 14 size 40 for 383
# Run 15 size 31 for 383
# Run 16 size 71 for 383
# Run 17 size 32 for 383
# Run 18 size 36 for 383
# Run 19 size 41 for 383
# Run 20 size 63 for 383
# Run 21 size 32 for 383
# Run 22 size 57 for 383
# Run 23 size 62 for 383
# Run 24 size 70 for 383
# Run 25 size 49 for 383
# Run 26 size 41 for 383
# Run 27 size 32 for 383
# Run 28 size 32 for 383
# Run 29 size 60 for 383
# Run 30 size 78 for 383
# Run 31 size 62 for 383
# Run 32 size 45 for 383
# Run 33 size 47 for 383
# Run 34 size 50 for 383
# Run 35 size 32 for 383
# Run 36 size 40 for 383
# Run 37 size 40 for 383
# Run 38 size 37 for 383
# Run 39 size 33 for 383
# Run 40 size 39 for 383
# Run 41 size 49 for 383
# Run 42 size 54 for 383
# Run 43 size 34 for 383
# Run 44 size 34 for 383
# Run 45 size 50 for 383
# Run 46 size 37 for 383
# Run 47 size 35 for 383
# Run 48 size 32 for 383
# Run 49 size 52 for 383
# Run 50 size 45 for 383
# Run 51 size 44 for 383
# Run 52 size 31 for 383
# Run 53 size 39 for 383
# Run 54 size 34 for 383
# Run 55 size 32 for 383
# Run 56 size 42 for 383
# Run 57 size 56 for 383
# Run 58 size 45 for 383
# Run 59 size 32 for 383
# Run 60 size 81 for 383
# Run 61 size 49 for 383
# Run 62 size 44 for 383
# Run 63 size 42 for 383
# Run 64 size 41 for 383
# Run 65 size 55 for 383
# Run 66 size 53 for 383
# Run 67 size 45 for 383
# Run 68 size 48 for 383
# Run 69 size 67 for 383
# Run 70 size 52 for 383
# Run 71 size 43 for 383
# Run 72 size 34 for 383
# Run 73 size 64 for 383
# Run 74 size 41 for 383
# Run 75 size 88 for 383
# Run 76 size 47 for 383
# Run 77 size 78 for 383
# Run 78 size 108 for 383
# Run 79 size 35 for 383
# Run 80 size 45 for 383
# Run 81 size 37 for 383
# Run 82 size 84 for 383
# Run 83 size 49 for 383
# Run 84 size 34 for 383
# Run 85 size 68 for 383
# Run 86 size 42 for 383
# Run 87 size 42 for 383
# Run 88 size 130 for 383
# Run 89 size 33 for 383
# Run 90 size 75 for 383
# Run 91 size 33 for 383
# Run 92 size 48 for 383
# Run 93 size 31 for 383
# Run 94 size 57 for 383
# Run 95 size 33 for 383
# Run 96 size 45 for 383
# Run 97 size 50 for 383
# Run 98 size 40 for 383
# Run 99 size 82 for 383
# Run 100 size 46 for 383
# Run 101 size 56 for 383
# Run 102 size 31 for 383
# Run 103 size 31 for 383
# Run 104 size 70 for 383
# Run 105 size 42 for 383
# Run 106 size 41 for 383
# Run 107 size 42 for 383
# Run 108 size 48 for 383
# Run 109 size 35 for 383
# Run 110 size 36 for 383
# Run 111 size 40 for 383
# Run 112 size 32 for 383
# Run 113 size 38 for 383
# Run 114 size 31 for 383
# Run 115 size 35 for 383
# Run 116 size 31 for 383
# Run 117 size 36 for 383
# Run 118 size 33 for 383
# Run 119 size 33 for 383
# Run 120 size 44 for 383
# Run 121 size 48 for 383
# Run 122 size 49 for 383
# Run 123 size 37 for 383
# Run 124 size 75 for 383
# Run 125 size 48 for 383
# Run 126 size 47 for 383
# Run 127 size 59 for 383
# Run 128 size 35 for 383
# Run 129 size 57 for 383
# Run 130 size 38 for 383
# Run 131 size 55 for 383
# Run 132 size 56 for 383
# Run 133 size 50 for 383
# Run 134 size 44 for 383
# Run 135 size 38 for 383
# Run 136 size 47 for 383
# Run 137 size 81 for 383
# Run 138 size 32 for 383
# Run 139 size 38 for 383
# Run 140 size 34 for 383
# Run 141 size 37 for 383
# Run 142 size 45 for 383
# Run 143 size 63 for 383
# Run 144 size 40 for 383
# Run 145 size 38 for 383
# Run 146 size 34 for 383
# Run 147 size 31 for 383
# Run 148 size 32 for 383
# Run 149 size 55 for 383
# Run 150 size 44 for 383
# Run 151 size 36 for 383
# Run 152 size 39 for 383
# Run 153 size 43 for 383
# Run 154 size 57 for 383
# Run 155 size 42 for 383
# Run 156 size 39 for 383
# Run 157 size 88 for 383
# Run 158 size 32 for 383
# Run 159 size 37 for 383
# Run 160 size 31 for 383
# Run 161 size 57 for 383
# Run 162 size 31 for 383
# Run 163 size 48 for 383
# Run 164 size 31 for 383
# Run 165 size 40 for 383
# Run 166 size 31 for 383
# Run 167 size 33 for 383
# Run 168 size 132 for 383
# Run 169 size 59 for 383
# Run 170 size 45 for 383
# Run 171 size 38 for 383
# Run 172 size 34 for 383
# Run 173 size 38 for 383
# Run 174 size 73 for 383
# Run 175 size 34 for 383
# Run 176 size 41 for 383
# Run 177 size 50 for 383
# Run 178 size 38 for 383
# Run 179 size 33 for 383
# Run 180 size 104 for 383
# Run 181 size 55 for 383
# Run 182 size 57 for 383
# Run 183 size 39 for 383
# Run 184 size 32 for 383
# Run 185 size 39 for 383
# Run 186 size 49 for 383
# Run 187 size 41 for 383
# Run 188 size 38 for 383
# Run 189 size 31 for 383
# Run 190 size 77 for 383
# Run 191 size 31 for 383
# Run 192 size 48 for 383
# Run 193 size 90 for 383
# Run 194 size 32 for 383
# Run 195 size 53 for 383
# Run 196 size 70 for 383
# Run 197 size 31 for 383
# Run 198 size 42 for 383
# Run 199 size 43 for 383
# Run 200 size 68 for 383
# Run 201 size 40 for 383
# Run 202 size 56 for 383
# Run 203 size 57 for 383
# Run 204 size 32 for 383
# Run 205 size 34 for 383
# Run 206 size 59 for 383
# Run 207 size 40 for 383
# Run 208 size 79 for 383
# Run 209 size 41 for 383
# Run 210 size 39 for 383
# Run 211 size 119 for 383
# Run 212 size 44 for 383
# Run 213 size 53 for 383
# Run 214 size 140 for 383
# Run 215 size 45 for 383
# Run 216 size 51 for 383
# Run 217 size 32 for 383
# Run 218 size 41 for 383
# Run 219 size 35 for 383
# Run 220 size 33 for 383
# Run 221 size 106 for 383
# Run 222 size 37 for 383
# Run 223 size 61 for 383
# Run 224 size 35 for 383
# Run 225 size 38 for 383
# Run 226 size 47 for 383
# Run 227 size 49 for 383
# Run 228 size 31 for 383
# Run 229 size 32 for 383
# Run 230 size 89 for 383
# Run 231 size 31 for 383
# Run 232 size 64 for 383
# Run 233 size 48 for 383
# Run 234 size 88 for 383
# Run 235 size 103 for 383
# Run 236 size 50 for 383
# Run 237 size 50 for 383
# Run 238 size 33 for 383
# Run 239 size 45 for 383
# Run 240 size 34 for 383
# Run 241 size 81 for 383
# Run 242 size 38 for 383
# Run 243 size 90 for 383
# Run 244 size 36 for 383
# Run 245 size 43 for 383
# Run 246 size 104 for 383
# Run 247 size 39 for 383
# Run 248 size 53 for 383
# Run 249 size 46 for 383
# Run 250 size 37 for 383
# Run 251 size 34 for 383
# Run 252 size 36 for 383
# Run 253 size 33 for 383
# Run 254 size 40 for 383
# Run 255 size 47 for 383
# Run 256 size 49 for 383
# Run 257 size 63 for 383
# Run 258 size 53 for 383
# Run 259 size 32 for 383
# Run 260 size 42 for 383
# Run 261 size 36 for 383
# Run 262 size 55 for 383
# Run 263 size 63 for 383
# Run 264 size 35 for 383
# Run 265 size 31 for 383
# Run 266 size 65 for 383
# Run 267 size 43 for 383
# Run 268 size 31 for 383
# Run 269 size 34 for 383
# Run 270 size 31 for 383
# Run 271 size 38 for 383
# Run 272 size 35 for 383
# Run 273 size 31 for 383
# Run 274 size 41 for 383
# Run 275 size 35 for 383
# Run 276 size 31 for 383
# Run 277 size 68 for 383
# Run 278 size 46 for 383
# Run 279 size 33 for 383
# Run 280 size 39 for 383
# Run 281 size 40 for 383
# Run 282 size 201 for 383
# Run 283 size 36 for 383
# Run 284 size 54 for 383
# Run 285 size 34 for 383
# Run 286 size 38 for 383
# Run 287 size 116 for 383
# Run 288 size 101 for 383
# Run 289 size 71 for 383
# Run 290 size 111 for 383
# Run 291 size 51 for 383
# Run 292 size 121 for 383
# Run 293 size 48 for 383
# Run 294 size 31 for 383
# Run 295 size 36 for 383
# Run 296 size 45 for 383
# Run 297 size 32 for 383
# Run 298 size 54 for 383
# Run 299 size 43 for 383
# Run 300 size 32 for 383
# Run 301 size 108 for 383
# Run 302 size 39 for 383
# Run 303 size 35 for 383
# Run 304 size 48 for 383
# Run 305 size 35 for 383
# Run 306 size 31 for 383
# Run 307 size 37 for 383
# Run 308 size 40 for 383
# Run 309 size 83 for 383
# Run 310 size 41 for 383
# Run 311 size 45 for 383
# Run 312 size 31 for 383
# Run 313 size 65 for 383
# Run 314 size 63 for 383
# Run 315 size 43 for 383
# Run 316 size 40 for 383
# Run 317 size 33 for 383
# Run 318 size 33 for 383
# Run 319 size 51 for 383
# Run 320 size 147 for 383
# Run 321 size 39 for 383
# Run 322 size 32 for 383
# Run 323 size 48 for 383
# Run 324 size 65 for 383
# Run 325 size 32 for 383
# Run 326 size 125 for 383
# Run 327 size 31 for 383
# Run 328 size 63 for 383
# Run 329 size 95 for 383
# Run 330 size 32 for 383
# Run 331 size 133 for 383
# Run 332 size 49 for 383
# Run 333 size 76 for 383
# Run 334 size 35 for 383
# Run 335 size 40 for 383
# Run 336 size 58 for 383
# Run 337 size 219 for 383
# Run 338 size 34 for 383
# Run 339 size 33 for 383
# Run 340 size 37 for 383
# Run 341 size 57 for 383
# Run 342 size 37 for 383
# Run 343 size 33 for 383
# Run 344 size 41 for 383
# Run 345 size 71 for 383
# Run 346 size 32 for 383
# Run 347 size 31 for 383
# Run 348 size 351 for 383
# Run 349 size 131 for 383
# Run 350 size 59 for 383
# Run 351 size 32 for 383
# Run 352 size 48 for 383
# Run 353 size 43 for 383
# Run 354 size 42 for 383
# Run 355 size 54 for 383
# Run 356 size 101 for 383
# Run 357 size 165 for 383
# Run 358 size 38 for 383
# Run 359 size 35 for 383
# Run 360 size 33 for 383
# Run 361 size 52 for 383
# Run 362 size 95 for 383
# Run 363 size 50 for 383
# Run 364 size 41 for 383
# Run 365 size 35 for 383
# Run 366 size 74 for 383
# Run 367 size 123 for 383
# Run 368 size 139 for 383
# Run 369 size 38 for 383
# Run 370 size 36 for 383
# Run 371 size 48 for 383
# Run 372 size 84 for 383
# Run 373 size 40 for 383
# Run 374 size 62 for 383
# Run 375 size 48 for 383
# Run 376 size 56 for 383
# Run 377 size 93 for 383
# Run 378 size 82 for 383
# Run 379 size 36 for 383
# Run 380 size 54 for 383
# Run 381 size 49 for 383
# Run 382 size 33 for 383
# Run 383 size 35 for 383

# %%
#AllReviews.to_csv('data/eletronic_sample_counts.csv.gz', compression='gzip')

# %%
print len(AllReviews[AllReviews.revRank>0])
print len(AllReviews[AllReviews.powerWithStar>0])
# Out:
# 19680
# 19756

# %%
AllReviews = AllReviews[AllReviews.revRank>0]
AllReviews.shape
# Out:
# (19680, 33)

# %%
ndcg_pr_hs_len=ndcg.calc_ndcg(AllReviews,'revRank',1) 
print "revRank ndcg 1="+str(np.mean(ndcg_pr_hs_len))
ndcg_pr_hs_len=ndcg.calc_ndcg(AllReviews,'revRank',3) 
print "revRank ndcg 3="+str(np.mean(ndcg_pr_hs_len))
ndcg_pr_hs_len=ndcg.calc_ndcg(AllReviews,'revRank',5) 
print "revRank ndcg 5="+str(np.mean(ndcg_pr_hs_len))
#revRank ndcg 1=0.914285714286
#revRank ndcg 3=0.896109540119
#revRank ndcg 5=0.862381460188
# Out:
# revRank ndcg 1=0.914285714286
# revRank ndcg 3=0.896109540119
# revRank ndcg 5=0.862381460188

# %%
ndcg_mhr=ndcg.calc_ndcg(AllReviews,'powerWithStar',1) 
print "MHR ndcg 1="+str(np.mean(ndcg_mhr))
ndcg_mhr=ndcg.calc_ndcg(AllReviews,'powerWithStar',3) 
print "MHR ndcg 3="+str(np.mean(ndcg_mhr))
ndcg_mhr=ndcg.calc_ndcg(AllReviews,'powerWithStar',5) 
print "MHR ndcg 5="+str(np.mean(ndcg_mhr))
# Out:
# MHR ndcg 1=0.751322751323
# MHR ndcg 3=0.837819412086
# MHR ndcg 5=0.82686792279
