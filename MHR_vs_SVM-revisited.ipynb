# %%
import pandas as pd
import numpy as np

from sklearn.svm import SVR, LinearSVR
from sklearn.grid_search import GridSearchCV
from scipy.stats import spearmanr
from sklearn.metrics import make_scorer
from time import time
from sklearn import svm
from sklearn import cross_validation
from sklearn.feature_extraction.text import TfidfVectorizer

import MHR as mhr

def simple_spearman(x,y): return np.abs(spearmanr(x,y)[0])
spearmanr_scorer = make_scorer(simple_spearman)

# %%
def reload_package(root_module):
    package_name = root_module.__name__

    # get a reference to each loaded module
    loaded_package_modules = dict([
        (key, value) for key, value in sys.modules.items() 
        if key.startswith(package_name) and isinstance(value, types.ModuleType)])

    # delete references to these loaded modules from sys.modules
    for key in loaded_package_modules:
        del sys.modules[key]

    # load each of the modules again; 
    # make old modules share state with new modules
    for key in loaded_package_modules:
        print 'loading %s' % key
        newmodule = __import__(key)
        oldmodule = loaded_package_modules[key]
        oldmodule.__dict__.clear()
        oldmodule.__dict__.update(newmodule.__dict__)
        
def dcg_at_k(r, k, method=0):
    r = np.asfarray(r)[:k]
    if r.size:
        if method == 0:
            return r[0] + np.sum(r[1:] / np.log2(np.arange(2, r.size + 1)))
        elif method == 1:
            return np.sum(r / np.log2(np.arange(2, r.size + 2)))
        else:
            raise ValueError('method must be 0 or 1.')
    return 0.


def ndcg_at_k(r, k, method=0):
    dcg_max = dcg_at_k(sorted(r, reverse=True), k, method)
    if not dcg_max:
        return 0.
    return dcg_at_k(r, k, method) / dcg_max


def calc_ndcg(df, column,k):
    min_votes=5
    min_comments=30

    ndcg_global=[]
    grouped=df.groupby('asin')

    for name, group in grouped:
        dffiltro = (df['asin']==name)
        
        values_test = df[dffiltro]['helpfulness'].values
        scores = df[dffiltro][column].values


        ind = (-np.array(scores)).argsort()
        a = np.array(values_test)[ind]	
        ndcg = ndcg_at_k(a, k)
        ndcg_global.append(ndcg)
    return ndcg_global

def calc_ndcg_mean(df, column,k):
    x = calc_ndcg(df,column,k)
    return np.mean(x)

def calc_corr(df, column):
    correlation=[]
    grouped=df.groupby('asin')

    for name, group in grouped:
        dffiltro = (df['asin']==name)
        
        helpfulness = df[dffiltro]['helpfulness'].values
        scores = df[dffiltro][column].values
        correlation.append(np.corrcoef(helpfulness,scores)[0][1])
    return correlation

# %%
reviews_features = pd.read_csv('data/eletronic_sample_counts.csv.gz')
reviews_features.shape
# Out:
# /usr/local/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (10,11,17,19,20,21,22,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (40870, 34)

# %%
#split by product
min_comments=30
min_votes=5

reviews_features=reviews_features.dropna()
grouped=reviews_features[reviews_features['tot'].astype(int)>min_votes].groupby('asin')
total = len(grouped)
performance=[]

# %%
run = 0
svmPrediction = pd.DataFrame()

for name, group in grouped:

    try:
    
        dffiltro = (reviews_features['asin']==name) & (reviews_features['tot'].astype(int)>min_votes)
        reviews_set = reviews_features[dffiltro]
        run += 1
        print("Run %d size %d for %d: %s" % (run, len(reviews_set), total, name))

        #if len(reviews_set) < 30: continue

        #CROSVALIDATION BY COMMENTS
        clf = svm.SVR()
        max_ndcg=0
        bestSVMPrediction=pd.DataFrame()

        features = TfidfVectorizer().fit_transform(reviews_set.reviewText)
        rs = cross_validation.ShuffleSplit(len(reviews_set), n_iter=10, test_size=.1 , random_state=0)
        ind=0
        ndcg=[]
        for train_index, test_index in rs:
            #train
            features_train = features[train_index]
            labels_train = reviews_set.iloc[train_index]["helpfulness"].values
            clf.fit(features_train, labels_train)

            #test
            features_test = features[test_index]
            labels_test = reviews_set.iloc[test_index]["helpfulness"].values
            x=clf.predict(features_test)

            dfTest= reviews_set.iloc[test_index]
            dfTest['svm']=x
            local_ndcg = calc_ndcg_mean(dfTest,'svm',5)
            ndcg.append(local_ndcg)
            #print "ndcg at fold "+str(ind)+" = "+ str(local_ndcg)

            ind=ind+1

            if (local_ndcg>max_ndcg):
                bestSVMPrediction=dfTest

        print "mean: " + str(np.mean(ndcg))
        svmPrediction = svmPrediction.append(bestSVMPrediction)

    except:
        
        print "mean: error"
        
    #if run > 4:
        #break

#save bestSVMPrediction on csv
svmPrediction.to_csv('data/best_prediction_svm_revisited.csv')
svmPrediction.shape
# Out:
# Run 1 size 40 for 383: 1400532655
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# mean: 0.961705052938
# Run 2 size 33 for 383: B00000J061
# mean: 0.982108409374
# Run 3 size 31 for 383: B00001P4ZH
# mean: 0.956283883991
# Run 4 size 32 for 383: B00001WRSJ
# mean: 0.9397043491
# Run 5 size 35 for 383: B000031KIM
# mean: 0.925188242331
# Run 6 size 35 for 383: B00004SB92
# mean: 0.965209767023
# Run 7 size 34 for 383: B00004THCZ
# mean: 0.970023208384
# Run 8 size 45 for 383: B00004XOM3
# mean: 0.97889846974
# Run 9 size 32 for 383: B00004ZCJE
# mean: 0.933281345404
# Run 10 size 39 for 383: B000053HC5
# mean: 0.981345325
# Run 11 size 68 for 383: B000053HH5
# mean: 0.91103966808
# Run 12 size 57 for 383: B00005LEN4
# mean: 0.872203066685
# Run 13 size 40 for 383: B000062VUO
# mean: 0.92397724065
# Run 14 size 40 for 383: B00006B7DA
# mean: 0.982626357541
# Run 15 size 31 for 383: B00006HMPK
# mean: 0.977584654494
# Run 16 size 71 for 383: B00006I53S
# mean: 0.938474192205
# Run 17 size 32 for 383: B00006I53X
# mean: 0.957578890095
# Run 18 size 36 for 383: B00006IS4X
# mean: 0.968720147146
# Run 19 size 41 for 383: B00006RVPW
# mean: 0.917930379642
# Run 20 size 63 for 383: B00007E7JU
# mean: 0.908075217182
# Run 21 size 32 for 383: B00007EDZG
# mean: 0.959084164794
# Run 22 size 57 for 383: B00007GQLS
# mean: 0.925770096949
# Run 23 size 62 for 383: B00007GQLU
# mean: 0.915398478432
# Run 24 size 70 for 383: B00007KDVI
# mean: 0.880938303603
# Run 25 size 49 for 383: B000089GN2
# mean: 0.969917655064
# Run 26 size 41 for 383: B000089GN3
# mean: 0.973185433054
# Run 27 size 32 for 383: B00008OE6I
# mean: 0.961754988322
# Run 28 size 32 for 383: B00009R6TA
# mean: 0.949795927506
# Run 29 size 60 for 383: B00009R6WO
# mean: 0.942446645802
# Run 30 size 78 for 383: B00009R6WT
# mean: 0.916437441614
# Run 31 size 62 for 383: B00009XVCZ
# mean: 0.931183467909
# Run 32 size 45 for 383: B0000A1G05
# mean: 0.975327839698
# Run 33 size 47 for 383: B0000BZL1P
# mean: 0.969557367687
# Run 34 size 50 for 383: B0000C8VEK
# mean: 0.954692769409
# Run 35 size 32 for 383: B0000CE1UO
# mean: 0.985374935864
# Run 36 size 40 for 383: B0000DB4D1
# mean: 0.983819450632
# Run 37 size 40 for 383: B000144I2Q
# mean: 0.962089019982
# Run 38 size 37 for 383: B00018MSNI
# mean: 0.977428004156
# Run 39 size 33 for 383: B0001D3K8A
# mean: 0.97501273632
# Run 40 size 39 for 383: B0001FSCZO
# mean: 0.96522974425
# Run 41 size 49 for 383: B0001FTVEK
# mean: 0.970073486257
# Run 42 size 54 for 383: B000204SWE
# mean: 0.875396584741
# Run 43 size 34 for 383: B0002A0206
# mean: 0.975420137716
# Run 44 size 34 for 383: B0002GDIII
# mean: 0.956231643115
# Run 45 size 50 for 383: B0002OZXHO
# mean: 0.966991014796
# Run 46 size 37 for 383: B0002UM0JW
# mean: 0.972919525257
# Run 47 size 35 for 383: B0002XQJFA
# mean: 0.987216053778
# Run 48 size 32 for 383: B0002XQWCK
# mean: 0.939269551037
# Run 49 size 52 for 383: B0002Y5WXE
# mean: 0.939353224414
# Run 50 size 45 for 383: B0002Y5WXO
# mean: 0.978811442897
# Run 51 size 44 for 383: B0002ZAILY
# mean: 0.912370764886
# Run 52 size 31 for 383: B0002ZAIM8
# mean: 0.965028675576
# Run 53 size 39 for 383: B0002ZW5W4
# mean: 0.962575912871
# Run 54 size 34 for 383: B000629GES
# mean: 0.970315145724
# Run 55 size 32 for 383: B00066EK2W
# mean: 0.977693583856
# Run 56 size 42 for 383: B00067TTY0
# mean: 0.96582490086
# Run 57 size 56 for 383: B00077AA5Q
# mean: 0.927632563606
# Run 58 size 45 for 383: B0007LJHVA
# mean: 0.969614411596
# Run 59 size 23 for 383: B0007MXZB2
# mean: error
# Run 60 size 81 for 383: B0007QKMQY
# mean: 0.872358105322
# Run 61 size 49 for 383: B0007U00X0
# mean: 0.956405706397
# Run 62 size 44 for 383: B0007U0GZM
# mean: 0.943289396625
# Run 63 size 42 for 383: B0007VMROE
# mean: 0.949604398971
# Run 64 size 41 for 383: B0007Y791C
# mean: 0.980273385339
# Run 65 size 55 for 383: B0007Y794O
# mean: 0.899974015943
# Run 66 size 52 for 383: B0007Y79B2
# mean: 0.928310083867
# Run 67 size 45 for 383: B00093IIRA
# mean: 0.943049502899
# Run 68 size 48 for 383: B0009GZAGO
# mean: 0.974888236663
# Run 69 size 67 for 383: B0009GZSSO
# mean: 0.930274400732
# Run 70 size 52 for 383: B000A3WS84
# mean: 0.933446868763
# Run 71 size 43 for 383: B000A5TAT2
# mean: 0.963363103372
# Run 72 size 34 for 383: B000AJIF4E
# mean: 0.975225776371
# Run 73 size 64 for 383: B000AP05BO
# mean: 0.927909437496
# Run 74 size 41 for 383: B000AYJDD6
# mean: 0.983621961961
# Run 75 size 88 for 383: B000AZ57M6
# mean: 0.952091196151
# Run 76 size 47 for 383: B000BI2180
# mean: 0.963862821897
# Run 77 size 78 for 383: B000BI7NHY
# mean: 0.941759411344
# Run 78 size 108 for 383: B000BKJZ9Q
# mean: 0.910437927963
# Run 79 size 35 for 383: B000BP50AY
# mean: 0.962409925596
# Run 80 size 45 for 383: B000BTL0OA
# mean: 0.964442066044
# Run 81 size 37 for 383: B000BY52NK
# mean: 0.978066809691
# Run 82 size 84 for 383: B000CS7U1C
# mean: 0.866954291386
# Run 83 size 49 for 383: B000CSOXTO
# mean: 0.967055854372
# Run 84 size 33 for 383: B000EMWBT2
# mean: 0.982532051647
# Run 85 size 68 for 383: B000EMWBV0
# mean: 0.943914160255
# Run 86 size 42 for 383: B000EPHR0C
# mean: 0.953621064947
# Run 87 size 42 for 383: B000EPJL1A
# mean: 0.943570120945
# Run 88 size 130 for 383: B000EPLP3C
# mean: 0.84761910269
# Run 89 size 33 for 383: B000EPNDEG
# mean: 0.973064334758
# Run 90 size 75 for 383: B000EW8074
# mean: 0.906678823638
# Run 91 size 33 for 383: B000EXR0SI
# mean: 0.970044959835
# Run 92 size 48 for 383: B000FBK3QK
# mean: 0.934793295362
# Run 93 size 31 for 383: B000GHTGES
# mean: 0.998640806478
# Run 94 size 57 for 383: B000HAOVGM
# mean: 0.938112815702
# Run 95 size 33 for 383: B000HATNI8
# mean: 0.966337615559
# Run 96 size 45 for 383: B000HGIWN4
# mean: 0.97560463053
# Run 97 size 50 for 383: B000HJPK2C
# mean: 0.965248983185
# Run 98 size 40 for 383: B000I1X3W8
# mean: 0.975762253725
# Run 99 size 82 for 383: B000I1X6PM
# mean: 0.934786792387
# Run 100 size 46 for 383: B000I1YIDQ
# mean: 0.946284975351
# Run 101 size 56 for 383: B000I1ZWRC
# mean: 0.915414335876
# Run 102 size 31 for 383: B000I661J0
# mean: 0.973083447604
# Run 103 size 31 for 383: B000IE8Z4Q
# mean: 0.974616316174
# Run 104 size 70 for 383: B000IJV4BC
# mean: 0.927202331308
# Run 105 size 42 for 383: B000J36XR2
# mean: 0.984514614679
# Run 106 size 41 for 383: B000JMJWV2
# mean: 0.990262674555
# Run 107 size 42 for 383: B000JVCPEY
# mean: 0.932634578143
# Run 108 size 48 for 383: B000KJQ1DG
# mean: 0.961735056603
# Run 109 size 35 for 383: B000KKPN5C
# mean: 0.94856912185
# Run 110 size 36 for 383: B000LRMS66
# mean: 0.992903791983
# Run 111 size 40 for 383: B000MW3YE0
# mean: 0.960638885271
# Run 112 size 32 for 383: B000NP3DJW
# mean: 0.9315626266
# Run 113 size 38 for 383: B000NP46K2
# mean: 0.94603646349
# Run 114 size 31 for 383: B000NVVDKC
# mean: 0.964959406308
# Run 115 size 35 for 383: B000O161X0
# mean: 0.947620510766
# Run 116 size 31 for 383: B000OH63MI
# mean: 0.946561959184
# Run 117 size 36 for 383: B000OMKR8E
# mean: 0.972883898332
# Run 118 size 33 for 383: B000Q3043Y
# mean: 0.983313150638
# Run 119 size 33 for 383: B000QUUFRW
# mean: 0.955910285307
# Run 120 size 44 for 383: B000RZDBM2
# mean: 0.989136212671
# Run 121 size 47 for 383: B000U62N1S
# mean: 0.948127426659
# Run 122 size 49 for 383: B000UF3FT8
# mean: 0.814093661927
# Run 123 size 37 for 383: B000UV4EU6
# mean: 0.947539239522
# Run 124 size 75 for 383: B000V1MLBE
# mean: 0.917800894391
# Run 125 size 48 for 383: B000V1VG5G
# mean: 0.97839552985
# Run 126 size 47 for 383: B000V5P90K
# mean: 0.952093791774
# Run 127 size 59 for 383: B000VDCT3C
# mean: 0.89242441801
# Run 128 size 35 for 383: B000VDCTCI
# mean: 0.934729347865
# Run 129 size 57 for 383: B000VJX7DW
# mean: 0.965311374056
# Run 130 size 38 for 383: B000WG6XW6
# mean: 0.937566343868
# Run 131 size 55 for 383: B000Z80ICM
# mean: 0.961142917373
# Run 132 size 56 for 383: B00119T6NQ
# mean: 0.867867322233
# Run 133 size 50 for 383: B0011NVMO8
# mean: 0.957515691872
# Run 134 size 44 for 383: B0011Z44UA
# mean: 0.997548745447
# Run 135 size 38 for 383: B0012Y6HC8
# mean: 0.983215154263
# Run 136 size 47 for 383: B0013A1XDE
# mean: 0.953503369748
# Run 137 size 81 for 383: B0013FRNKG
# mean: 0.882377432406
# Run 138 size 32 for 383: B0013FW8XS
# mean: 0.957611516227
# Run 139 size 38 for 383: B0014CIBWC
# mean: 0.97771574607
# Run 140 size 31 for 383: B0014F9U6U
# mean: 0.986034405112
# Run 141 size 37 for 383: B001542X64
# mean: 0.965109667406
# Run 142 size 45 for 383: B0018LX0DY
# mean: 0.967113494223
# Run 143 size 63 for 383: B001BTCSI6
# mean: 0.910696111245
# Run 144 size 40 for 383: B001CCAISE
# mean: 0.980872880299
# Run 145 size 38 for 383: B001CCLBSA
# mean: 0.982807354304
# Run 146 size 34 for 383: B001CCLBSU
# mean: 0.952206158196
# Run 147 size 31 for 383: B001D8S9E2
# mean: 0.935204157169
# Run 148 size 32 for 383: B001DYC0CS
# mean: 0.982861392534
# Run 149 size 42 for 383: B001ENOZY4
# mean: error
# Run 150 size 44 for 383: B001EQ4BVI
# mean: 0.908907490063
# Run 151 size 36 for 383: B001EYV9TM
# mean: 0.966440127119
# Run 152 size 39 for 383: B001F0RPGG
# mean: 0.968976808692
# Run 153 size 43 for 383: B001F7AHOG
# mean: 0.967994876994
# Run 154 size 57 for 383: B001FA1NK0
# mean: 0.926471889972
# Run 155 size 42 for 383: B001FA1O18
# mean: 0.97791770357
# Run 156 size 39 for 383: B001FWYGJS
# mean: 0.938869652088
# Run 157 size 88 for 383: B001G5ZTLS
# mean: 0.957864908498
# Run 158 size 32 for 383: B001G5ZTPY
# mean: 0.992307281112
# Run 159 size 37 for 383: B001HSOFI2
# mean: 0.94179880062
# Run 160 size 31 for 383: B001ISKNKA
# mean: 0.965630326555
# Run 161 size 57 for 383: B001QFZMCO
# mean: 0.933135147939
# Run 162 size 31 for 383: B001RQ2YF0
# mean: 0.989783491775
# Run 163 size 47 for 383: B001S2PPT0
# mean: 0.976542984923
# Run 164 size 31 for 383: B001SER456
# mean: 0.963374044923
# Run 165 size 40 for 383: B001SER47O
# mean: 0.937564682284
# Run 166 size 31 for 383: B001V9LPT4
# mean: 0.979280537664
# Run 167 size 33 for 383: B001XURPQI
# mean: 0.974942802122
# Run 168 size 131 for 383: B002C7481G
# mean: 0.893734309531
# Run 169 size 59 for 383: B002EEP3MK
# mean: 0.926767937521
# Run 170 size 45 for 383: B002HWRJY4
# mean: 0.944806399524
# Run 171 size 38 for 383: B002IKLJU0
# mean: 0.94247100062
# Run 172 size 34 for 383: B002IKLJVE
# mean: 0.97437011268
# Run 173 size 38 for 383: B002JCSV8U
# mean: 0.940511276655
# Run 174 size 73 for 383: B002JPITXY
# mean: 0.897166696666
# Run 175 size 34 for 383: B002LARRDK
# mean: 0.956861819741
# Run 176 size 41 for 383: B002LITT3I
# mean: 0.963348727714
# Run 177 size 50 for 383: B002LITT42
# mean: 0.952641105148
# Run 178 size 38 for 383: B002MAPRYU
# mean: 0.972662366082
# Run 179 size 33 for 383: B002NEGTSI
# mean: 0.974111173972
# Run 180 size 104 for 383: B002NEGTTW
# mean: 0.914501963747
# Run 181 size 55 for 383: B002QEBMAK
# mean: 0.927331602601
# Run 182 size 57 for 383: B002S53LJ2
# mean: 0.923721134446
# Run 183 size 39 for 383: B002UT42UI
# mean: 0.945080801975
# Run 184 size 30 for 383: B002WE4HE2
# mean: 0.988241855703
# Run 185 size 39 for 383: B00328HR76
# mean: 0.977165012548
# Run 186 size 49 for 383: B0033PRWSW
# mean: 0.890573304408
# Run 187 size 41 for 383: B0035FZJHQ
# mean: 0.939341797161
# Run 188 size 38 for 383: B0035WTVZA
# mean: 0.98582687567
# Run 189 size 31 for 383: B0036WS4D4
# mean: 0.943626467524
# Run 190 size 77 for 383: B0038JE07O
# mean: 0.877542189613
# Run 191 size 31 for 383: B0038JECKY
# mean: 0.963734752834
# Run 192 size 48 for 383: B00395WIXA
# mean: 0.978629807167
# Run 193 size 90 for 383: B003LR7ME6
# mean: 0.836619911881
# Run 194 size 32 for 383: B003M2YT96
# mean: 0.974624563138
# Run 195 size 53 for 383: B003RAE19Q
# mean: 0.941308776045
# Run 196 size 70 for 383: B003WJR69E
# mean: 0.916809679951
# Run 197 size 31 for 383: B003XIJ3MW
# mean: 0.970111892158
# Run 198 size 42 for 383: B003XU6H8I
# mean: 0.959288396253
# Run 199 size 43 for 383: B003ZSHNEA
# mean: 0.959863554945
# Run 200 size 68 for 383: B003ZSHNGS
# mean: 0.946910168066
# Run 201 size 40 for 383: B003ZYF3LO
# mean: 0.962392942368
# Run 202 size 56 for 383: B0040JHVC2
# mean: 0.957776516132
# Run 203 size 57 for 383: B0040QE98O
# mean: 0.920062427851
# Run 204 size 32 for 383: B0041OSQB6
# mean: 0.99532053647
# Run 205 size 34 for 383: B0041Q38NU
# mean: 0.983311519204
# Run 206 size 59 for 383: B0041RSPR8
# mean: 0.941124260138
# Run 207 size 40 for 383: B0041RSPRS
# mean: 0.990091909393
# Run 208 size 79 for 383: B00426C57O
# mean: 0.853370890496
# Run 209 size 41 for 383: B00429N18S
# mean: 0.938004850479
# Run 210 size 39 for 383: B0042A8CW2
# mean: 0.955385122895
# Run 211 size 119 for 383: B0042X9LC4
# mean: 0.907203966225
# Run 212 size 44 for 383: B0043RS864
# mean: 0.932477828104
# Run 213 size 45 for 383: B0044YU60M
# mean: 0.974835114999
# Run 214 size 140 for 383: B0045FM6SU
# mean: 0.861343204021
# Run 215 size 45 for 383: B004BLK24S
# mean: 0.908975184581
# Run 216 size 51 for 383: B004EPV7TK
# mean: 0.908756554669
# Run 217 size 32 for 383: B004FLJVXM
# mean: 0.993403650087
# Run 218 size 41 for 383: B004G8HXXO
# mean: 0.981716126278
# Run 219 size 27 for 383: B004GCJEZU
# mean: 0.991543215839
# Run 220 size 33 for 383: B004HYFX0C
# mean: 0.98714247447
# Run 221 size 106 for 383: B004I43F9C
# mean: 0.906318461278
# Run 222 size 37 for 383: B004J3V7MO
# mean: 0.975611484797
# Run 223 size 61 for 383: B004J3V90Y
# mean: 0.936950521481
# Run 224 size 35 for 383: B004J3Y9U6
# mean: 0.945530944861
# Run 225 size 38 for 383: B004J3ZV62
# mean: 0.9781839746
# Run 226 size 47 for 383: B004J4VYEY
# mean: 0.922726977462
# Run 227 size 49 for 383: B004N6259G
# mean: 0.942877305944
# Run 228 size 31 for 383: B004OOTRPC
# mean: 0.948695287659
# Run 229 size 32 for 383: B004Q0PT3I
# mean: 0.95847619036
# Run 230 size 89 for 383: B004QK7HI8
# mean: 0.888295464568
# Run 231 size 31 for 383: B004SBI2PW
# mean: 0.971989700557
# Run 232 size 64 for 383: B004T9RR6I
# mean: 0.850132681809
# Run 233 size 48 for 383: B004TRYENE
# mean: 0.915914409756
# Run 234 size 88 for 383: B004U78J1G
# mean: 0.916591033428
# Run 235 size 103 for 383: B004UL34EY
# mean: 0.922817038186
# Run 236 size 46 for 383: B004V4IWHY
# mean: 0.971593113605
# Run 237 size 50 for 383: B004W2JKWG
# mean: 0.904995801443
# Run 238 size 27 for 383: B004XC6GJ0
# mean: 0.989428159809
# Run 239 size 44 for 383: B004XZL980
# mean: 0.95642828466
# Run 240 size 34 for 383: B004Z6NWAU
# mean: 0.902897059824
# Run 241 size 81 for 383: B00519RW1U
# mean: 0.816368580946
# Run 242 size 38 for 383: B0054JJ0QW
# mean: 0.960297052397
# Run 243 size 90 for 383: B0055D66V4
# mean: 0.926235185382
# Run 244 size 36 for 383: B0055P9K38
# mean: 0.985793805754
# Run 245 size 43 for 383: B0058UUR6E
# mean: 0.960406017506
# Run 246 size 104 for 383: B005CLPP84
# mean: 0.814545767427
# Run 247 size 39 for 383: B005CLPP8E
# mean: 0.926814967265
# Run 248 size 53 for 383: B005CT56F8
# mean: 0.904481287693
# Run 249 size 46 for 383: B005DIBHA6
# mean: 0.962881761571
# Run 250 size 37 for 383: B005DKZTMG
# mean: 0.924634723832
# Run 251 size 34 for 383: B005HMKKH4
# mean: 0.976843373486
# Run 252 size 36 for 383: B005HQ50SO
# mean: 0.987342865738
# Run 253 size 33 for 383: B005IHAIC0
# mean: 0.96053109314
# Run 254 size 40 for 383: B005IHAIEI
# mean: 0.981209611701
# Run 255 size 47 for 383: B005KBB79C
# mean: 0.978841049107
# Run 256 size 49 for 383: B005KOZNBW
# mean: 0.987648967947
# Run 257 size 63 for 383: B005MTME3U
# mean: 0.856680772876
# Run 258 size 53 for 383: B005MTMFHU
# mean: 0.915914194009
# Run 259 size 32 for 383: B005N130Y4
# mean: 0.963647112428
# Run 260 size 42 for 383: B005QFH86S
# mean: 0.953700726885
# Run 261 size 36 for 383: B005U0M9B8
# mean: 0.880566321747
# Run 262 size 55 for 383: B0063705PE
# mean: 0.895537484639
# Run 263 size 63 for 383: B0067PLM5E
# mean: 0.938333434032
# Run 264 size 29 for 383: B006GWO5WK
# mean: 0.993692820549
# Run 265 size 31 for 383: B006P88VSE
# mean: 0.969706533234
# Run 266 size 65 for 383: B006QB1RPY
# mean: 0.916473941349
# Run 267 size 43 for 383: B006R2N8VS
# mean: 0.891050137074
# Run 268 size 31 for 383: B006SOLITY
# mean: 0.959889128624
# Run 269 size 34 for 383: B006TAP096
# mean: 0.973481726447
# Run 270 size 31 for 383: B006U1YUW2
# mean: 0.967854017755
# Run 271 size 38 for 383: B006U1YUZE
# mean: 0.931083017401
# Run 272 size 35 for 383: B006UMM2BW
# mean: 0.974803793744
# Run 273 size 31 for 383: B006ZH0JBM
# mean: 0.982019445992
# Run 274 size 41 for 383: B006ZH0KVG
# mean: 0.982949260193
# Run 275 size 35 for 383: B00728ZBA2
# mean: 0.97606525086
# Run 276 size 31 for 383: B0073HSH8U
# mean: 0.993396109894
# Run 277 size 68 for 383: B00746LVOM
# mean: 0.927121640438
# Run 278 size 46 for 383: B00746W3HG
# mean: 0.977657479786
# Run 279 size 33 for 383: B00746YHV6
# mean: 0.980675477513
# Run 280 size 39 for 383: B0074703CM
# mean: 0.957534882203
# Run 281 size 40 for 383: B007471PZQ
# mean: 0.983614904054
# Run 282 size 200 for 383: B0074BW614
# mean: 0.841229074261
# Run 283 size 36 for 383: B0074FGLUM
# mean: 0.969441237494
# Run 284 size 54 for 383: B0074WDDN8
# mean: 0.938472071502
# Run 285 size 34 for 383: B00752R4PK
# mean: 0.987025152583
# Run 286 size 38 for 383: B0075SUK14
# mean: 0.981083774919
# Run 287 size 116 for 383: B0076AYNXM
# mean: 0.85920606318
# Run 288 size 101 for 383: B007FGYZFI
# mean: 0.895901906659
# Run 289 size 21 for 383: B007I5JT4S
# mean: 0.992819109196
# Run 290 size 111 for 383: B007M506WS
# mean: 0.924256043651
# Run 291 size 51 for 383: B007M50PTM
# mean: 0.929437378952
# Run 292 size 121 for 383: B007P4VOWC
# mean: 0.926757266932
# Run 293 size 48 for 383: B007P4YAPK
# mean: 0.959823034142
# Run 294 size 31 for 383: B007R5YDYA
# mean: 0.972631590483
# Run 295 size 36 for 383: B007TYUTY2
# mean: 0.961981430604
# Run 296 size 45 for 383: B007VGGFZU
# mean: 0.900951369032
# Run 297 size 32 for 383: B007Y8DJ22
# mean: 0.983521887406
# Run 298 size 54 for 383: B00829THEG
# mean: 0.901839135021
# Run 299 size 43 for 383: B00829THK0
# mean: 0.970592911651
# Run 300 size 32 for 383: B00834SJNA
# mean: 0.959323116323
# Run 301 size 108 for 383: B00889ST2G
# mean: 0.869008887958
# Run 302 size 39 for 383: B0088CJT4U
# mean: 0.969159370076
# Run 303 size 35 for 383: B00894YP00
# mean: 0.975744948213
# Run 304 size 48 for 383: B00894YWD0
# mean: 0.917135562127
# Run 305 size 35 for 383: B008ABOJKS
# mean: 0.970657455135
# Run 306 size 31 for 383: B008B488DI
# mean: 0.943025364864
# Run 307 size 37 for 383: B008CS5T76
# mean: 0.958669554218
# Run 308 size 40 for 383: B008EWNVI4
# mean: 0.943672766081
# Run 309 size 83 for 383: B008F4NL04
# mean: 0.926303380183
# Run 310 size 41 for 383: B008GVL9YQ
# mean: 0.991895263558
# Run 311 size 45 for 383: B008GVM9K4
# mean: 0.988185966729
# Run 312 size 31 for 383: B008I21EA2
# mean: 0.988600703427
# Run 313 size 65 for 383: B008MB6ZX0
# mean: 0.916018430312
# Run 314 size 63 for 383: B008MB70TI
# mean: 0.911317762894
# Run 315 size 43 for 383: B008NENG1A
# mean: 0.974442609432
# Run 316 size 40 for 383: B00902SFC4
# mean: 0.980104482773
# Run 317 size 33 for 383: B0090Z3QG6
# mean: 0.974581579027
# Run 318 size 33 for 383: B0092MD5UY
# mean: 0.946853676033
# Run 319 size 51 for 383: B0094NXBZ0
# mean: 0.920201700053
# Run 320 size 147 for 383: B0094NY3R0
# mean: 0.808390281653
# Run 321 size 39 for 383: B0096W1OCG
# mean: 0.96973066547
# Run 322 size 32 for 383: B0096YOQQA
# mean: 0.971981911698
# Run 323 size 48 for 383: B0096YOQRY
# mean: 0.938549238091
# Run 324 size 65 for 383: B0097BEF1S
# mean: 0.899505058381
# Run 325 size 32 for 383: B0097CXFCC
# mean: 0.971016065412
# Run 326 size 124 for 383: B0099XGZXA
# mean: 0.886238932848
# Run 327 size 31 for 383: B009B0MY6S
# mean: 0.967463347995
# Run 328 size 63 for 383: B009B0MZ1M
# mean: 0.931027976405
# Run 329 size 95 for 383: B009B0MZ8U
# mean: 0.930638780272
# Run 330 size 15 for 383: B009IBX7Z2
# mean: 1.0
# Run 331 size 78 for 383: B009LL9VDG
# mean: 0.971201024516
# Run 332 size 49 for 383: B009LRR5AQ
# mean: 0.986620591111
# Run 333 size 76 for 383: B009PK9S90
# mean: 0.917690132617
# Run 334 size 35 for 383: B009W8YQ6K
# mean: 0.9520978626
# Run 335 size 40 for 383: B009X3UW2G
# mean: 0.984528916173
# Run 336 size 58 for 383: B009XNBFJK
# mean: 0.937464689208
# Run 337 size 219 for 383: B00A3YN0Z0
# mean: 0.965755021049
# Run 338 size 34 for 383: B00AJHDZSI
# mean: 0.971797564285
# Run 339 size 33 for 383: B00ATM1MGA
# mean: 0.972854374325
# Run 340 size 37 for 383: B00ATM1MHO
# mean: 0.962321616826
# Run 341 size 57 for 383: B00ATM1MVA
# mean: 0.91423932131
# Run 342 size 37 for 383: B00AWKC0JM
# mean: 0.970724561908
# Run 343 size 33 for 383: B00AXTQQDS
# mean: 0.918318048271
# Run 344 size 41 for 383: B00BCGRTFK
# mean: 0.953375786501
# Run 345 size 71 for 383: B00BDS3N1G
# mean: 0.939472180083
# Run 346 size 32 for 383: B00BF9MUAS
# mean: 0.96622179254
# Run 347 size 31 for 383: B00BFDHVAS
# mean: 0.965866406926
# Run 348 size 348 for 383: B00BGA9WK2
# mean: 0.740831444982
# Run 349 size 58 for 383: B00BGGDVOO
# mean: 0.973311540633
# Run 350 size 59 for 383: B00BI9X7UC
# mean: 0.920070950531
# Run 351 size 32 for 383: B00BQ4F9ZA
# mean: 0.977137118576
# Run 352 size 48 for 383: B00BQH8UEY
# mean: 0.955644551966
# Run 353 size 43 for 383: B00BW6LTG0
# mean: 0.966051508697
# Run 354 size 42 for 383: B00BW6LXHA
# mean: 0.960071852839
# Run 355 size 54 for 383: B00BXF7I9M
# mean: 0.966681589156
# Run 356 size 101 for 383: B00CMEN95U
# mean: 0.862223595164
# Run 357 size 165 for 383: B00CMQTVK0
# mean: 0.805165199525
# Run 358 size 25 for 383: B00COYOAYW
# mean: 0.984996390928
# Run 359 size 35 for 383: B00D029NNA
# mean: 0.944819503394
# Run 360 size 33 for 383: B00D02AG7C
# mean: 0.935199832931
# Run 361 size 52 for 383: B00D02AHEO
# mean: 0.919763918393
# Run 362 size 95 for 383: B00D5Q75RC
# mean: 0.76175100634
# Run 363 size 50 for 383: B00DB3SH2G
# mean: 0.970004227172
# Run 364 size 41 for 383: B00DM8R866
# mean: 0.947801704945
# Run 365 size 35 for 383: B00DMJI9TA
# mean: 0.871359503022
# Run 366 size 74 for 383: B00DMS0GTC
# mean: 0.87650441542
# Run 367 size 47 for 383: B00DR0PDNE
# mean: 0.976982487876
# Run 368 size 139 for 383: B00DVFLJDS
# mean: 0.845034319503
# Run 369 size 38 for 383: B00DY2Y28M
# mean: 0.953119602787
# Run 370 size 36 for 383: B00E0EY7Z6
# mean: 0.985688549546
# Run 371 size 48 for 383: B00E3W15P0
# mean: 0.967423865617
# Run 372 size 84 for 383: B00EDSI7QO
# mean: 0.862626113506
# Run 373 size 40 for 383: B00EVVGAC6
# mean: 0.953966227919
# Run 374 size 62 for 383: B00F0DD0I6
# mean: 0.904726309667
# Run 375 size 48 for 383: B00F3F0EIU
# mean: 0.984272699553
# Run 376 size 56 for 383: B00F3SOHNU
# mean: 0.9475314701
# Run 377 size 69 for 383: B00FEE7B1I
# mean: 0.92288377195
# Run 378 size 82 for 383: B00FFJ0HUE
# mean: 0.924207408237
# Run 379 size 36 for 383: B00FNPD1OY
# mean: 0.961004768053
# Run 380 size 54 for 383: B00FOTF8M2
# mean: 0.852601873841
# Run 381 size 49 for 383: B00G2TK76A
# mean: 0.975415589267
# Run 382 size 33 for 383: B00HWMPRKM
# mean: 0.960148322362
# Run 383 size 35 for 383: B00HWMPRKW
# mean: 0.994023486085
# (2117, 35)

# %%
print "SVM ndcg@1="+str(calc_ndcg_mean(svmPrediction,'svm',1))
print "SVM ndcg@3="+str(calc_ndcg_mean(svmPrediction,'svm',3))
print "SVM ndcg@5="+str(calc_ndcg_mean(svmPrediction,'svm',5))
# Out:
# SVM ndcg@1=0.889869669906
# SVM ndcg@3=0.912010540576
# SVM ndcg@5=0.94621064186

# %%
#salvando csv
pd.DataFrame(calc_ndcg(svmPrediction,'svm',1)).to_csv('data/ndcg_1_svm_revisited.csv')
pd.DataFrame(calc_ndcg(svmPrediction,'svm',3)).to_csv('data/ndcg_3_svm_revisited.csv')
pd.DataFrame(calc_ndcg(svmPrediction,'svm',5)).to_csv('data/ndcg_5_svm_revisited.csv')
